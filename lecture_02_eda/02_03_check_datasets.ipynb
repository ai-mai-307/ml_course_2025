# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Taxi

# %%
taxi_train = pd.read_csv(
    filepath_or_buffer = r'D:\Datasets\new-york-city-taxi-fare-prediction\train.csv',

    )
taxi_train
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 0           2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1           2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2          2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3           2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4         2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                                 ...          ...                      ...
# 55423851   2014-03-15 03:28:00.00000070         14.0  2014-03-15 03:28:00 UTC
# 55423852    2009-03-24 20:46:20.0000002          4.2  2009-03-24 20:46:20 UTC
# 55423853    2011-04-02 22:04:24.0000004         14.1  2011-04-02 22:04:24 UTC
# 55423854    2011-10-26 05:57:51.0000002         28.9  2011-10-26 05:57:51 UTC
# 55423855   2014-12-12 11:33:00.00000015          7.5  2014-12-12 11:33:00 UTC
#
# ...

# %%
taxi_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55423856 entries, 0 to 55423855
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   key                object
#  1   fare_amount        float64
#  2   pickup_datetime    object
#  3   pickup_longitude   float64
#  4   pickup_latitude    float64
#  5   dropoff_longitude  float64
#  6   dropoff_latitude   float64
#  7   passenger_count    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ GB

# %%
taxi_train['pickup_datetime'] = pd.to_datetime(taxi_train['pickup_datetime'])
taxi_train['pickup_datetime']
# Out:
# 0          2009-06-15 17:26:21+00:00
# 1          2010-01-05 16:52:16+00:00
# 2          2011-08-18 00:35:00+00:00
# 3          2012-04-21 04:30:42+00:00
# 4          2010-03-09 07:51:00+00:00
#                       ...
# 55423851   2014-03-15 03:28:00+00:00
# 55423852   2009-03-24 20:46:20+00:00
# 55423853   2011-04-02 22:04:24+00:00
# 55423854   2011-10-26 05:57:51+00:00
# 55423855   2014-12-12 11:33:00+00:00
# Name: pickup_datetime, Length: 55423856, dtype: datetime64[ns, UTC]

# %% [markdown]
# ## accidents

# %%
accidents = pd.read_csv(
    filepath_or_buffer=r'D:\Datasets\UK_Accident\UK_Accident.csv',

).drop(columns=['Accident_Index', 'Unnamed: 0'])

accidents
# Out:
#          Location_Easting_OSGR  Location_Northing_OSGR  Longitude   Latitude  \
# 0                     525680.0                178240.0  -0.191170  51.489096
# 1                     524170.0                181650.0  -0.211708  51.520075
# 2                     524520.0                182240.0  -0.206458  51.525301
# 3                     526900.0                177530.0  -0.173862  51.482442
# 4                     528060.0                179040.0  -0.156618  51.495752
# ...                        ...                     ...        ...        ...
# 1504145               310037.0                597647.0  -3.417278  55.264773
# 1504146               321509.0                574063.0  -3.230255  55.054855
# 1504147               321337.0                566365.0  -3.230826  54.985668
# 1504148               323869.0                566853.0  -3.191397  54.990446
# 1504149               314072.0                579971.0  -3.348426  55.106700
#
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Location_Easting_OSGR                        1504049 non-null  float64
#  1   Location_Northing_OSGR                       1504150 non-null  float64
#  2   Longitude                                    1504049 non-null  float64
#  3   Latitude                                     1504150 non-null  float64
#  4   Police_Force                                 1504150 non-null  int64
#  5   Accident_Severity                            1504150 non-null  int64
#  6   Number_of_Vehicles                           1504150 non-null  int64
#  7   Number_of_Casualties                         1504150 non-null  int64
#  8   Date                                         1504150 non-null  object
# ...

# %%
target = accidents['Accident_Severity']
target = target.apply(lambda x: 1 if x >= 2 else 0)

data = accidents.drop(columns='Accident_Severity')

# %%
target.value_counts(normalize=True)
# Out:
# Accident_Severity
# 1    0.987075
# 0    0.012925
# Name: proportion, dtype: float64
